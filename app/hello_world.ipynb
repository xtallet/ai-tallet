# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Running cells with '.venv (Python 3.13.0)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/xtallet/xavi_repo/ai_makerspace/challenge/ai-tallet/code/ai-tallet/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
